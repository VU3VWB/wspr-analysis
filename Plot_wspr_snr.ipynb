# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
tstamp = np.loadtxt("VK5ARG_VK6CQ-2023-02.csv", usecols=0)
SNR = np.loadtxt("VK5ARG_VK6CQ-2023-02.csv", usecols=1)

plt.figure(figsize=(16,9))
plt.plot(tstamp, SNR)
